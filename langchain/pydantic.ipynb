# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("meta-llama/llama-4-scout-17b-16e-instruct", model_provider="groq")

# %%
from pydantic import BaseModel, Field

class Movie(BaseModel) :
    title : str = Field(description="Title of the movie goes here.")
    year : int = Field(description = "The year the movie was released in")
    director : str = Field(description= "The director of the movie")
    rating : float = Field(description="The movie's rating out of 10")


model_with_structure = model.with_structured_output(Movie)

# %%
res1 = model.invoke("Provid details about the movie Mission Impossible")
res1.text
# Out:
# "Here's a comprehensive overview of the Mission: Impossible movie franchise:\n\n**Introduction**\n\nThe Mission: Impossible franchise is a series of action-spy films based on the 1960s television series of the same name. The films follow Ethan Hunt (Tom Cruise), a secret agent working for the Impossible Mission Force (IMF), as he takes on high-stakes missions around the world.\n\n**Movie Details**\n\nHere are the details of each Mission: Impossible movie:\n\n### Mission: Impossible (1996)\n\n* **Release Date:** May 22, 1996\n* **Director:** Brian De Palma\n* **Cast:** Tom Cruise, Jon Voight, Emmanuelle Béart, Henry Czerny, Emilio Estevez, and Dougray Scott\n* **Plot:** Ethan Hunt, a skilled thief and secret agent, is framed for the theft of a highly classified document. He must clear his name and uncover the real culprit.\n* **Box Office:** $457.7 million (worldwide)\n\n### Mission: Impossible II (2000)\n\n* **Release Date:** May 24, 2000\n* **Director:** John Woo\n* **Cast:** Tom Cr
# ...

# %%
res2 = model_with_structure.invoke("Provid details about the movie Mission Impossible")
res2
# Out:
# Movie(title='Mission: Impossible', year=1996, director='Brian De Palma', rating=7.1)
